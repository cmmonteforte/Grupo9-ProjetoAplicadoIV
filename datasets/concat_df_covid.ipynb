# %%
import pandas as pd
import glob

# Lista todos os arquivos CSV na pasta atual
caminho_arquivos = glob.glob('*.csv')

# Cria uma lista para armazenar os DataFrames
lista_dfs = []

# Lê cada arquivo CSV e adiciona à lista
for arquivo in caminho_arquivos:
    df = pd.read_csv(arquivo, delimiter=';')
    lista_dfs.append(df)

# Concatena todos os DataFrames em um único DataFrame
df_final = pd.concat(lista_dfs, ignore_index=True)

# Exibe o DataFrame final
print(df_final)
# Out:
#                 regiao estado municipio  coduf    codmun  codRegiaoSaude  \
# 0               Brasil    NaN       NaN     76       NaN             NaN
# 1               Brasil    NaN       NaN     76       NaN             NaN
# 2               Brasil    NaN       NaN     76       NaN             NaN
# 3               Brasil    NaN       NaN     76       NaN             NaN
# 4               Brasil    NaN       NaN     76       NaN             NaN
# ...                ...    ...       ...    ...       ...             ...
# 10081349  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 10081350  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 10081351  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 10081352  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 10081353  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
#
#            nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  \
# 0                      NaN  2021-07-01         26       210147125.0
# 1                      NaN  2021-07-02         26       210147125.0
# 2                      NaN  2021-07-03         26       210147125.0
# 3                      NaN  2021-07-04         27       210147125.0
# 4                      NaN  2021-07-05         27       210147125.0
# ...                    ...         ...        ...               ...
# 10081349  DISTRITO FEDERAL  2024-06-26         26         3015268.0
# 10081350  DISTRITO FEDERAL  2024-06-27         26         3015268.0
# 10081351  DISTRITO FEDERAL  2024-06-28         26         3015268.0
# 10081352  DISTRITO FEDERAL  2024-06-29         26         3015268.0
# 10081353  DISTRITO FEDERAL  2024-06-30         27         3015268.0
#
#           casosAcumulado  casosNovos  obitosAcumulado  obitosNovos  \
# 0             18622304.0       65163           520095         2029
# 1             18687469.0       65165           521952         1857
# 2             18742025.0       54556           523587         1635
# 3             18769808.0       27783           524417          830
# 4             18792511.0       22703           525112          695
# ...                  ...         ...              ...          ...
# 10081349        946342.0           0            12009            0
# 10081350        946342.0           0            12009            0
# 10081351        946342.0           0            12009            0
# 10081352        946491.0         149            12009            0
# 10081353        946491.0           0            12009            0
#
#           Recuperadosnovos  emAcompanhamentoNovos  interior/metropolitana
# 0               16858632.0              1180443.0                     NaN
# 1               16931272.0              1170937.0                     NaN
# 2               16989351.0              1176166.0                     NaN
# 3               17033808.0              1184630.0                     NaN
# 4               17082876.0              1162515.0                     NaN
# ...                    ...                    ...                     ...
# 10081349               NaN                    NaN                     1.0
# 10081350               NaN                    NaN                     1.0
# 10081351               NaN                    NaN                     1.0
# 10081352               NaN                    NaN                     1.0
# 10081353               NaN                    NaN                     1.0
#
# [10081354 rows x 17 columns]

# %%
df_final.head()
# Out:
#    regiao estado municipio  coduf  codmun  codRegiaoSaude nomeRegiaoSaude  \
# 0  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 1  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 2  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 3  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 4  Brasil    NaN       NaN     76     NaN             NaN             NaN
#
#          data  semanaEpi  populacaoTCU2019  casosAcumulado  casosNovos  \
# 0  2021-07-01         26       210147125.0      18622304.0       65163
# 1  2021-07-02         26       210147125.0      18687469.0       65165
# 2  2021-07-03         26       210147125.0      18742025.0       54556
# 3  2021-07-04         27       210147125.0      18769808.0       27783
# 4  2021-07-05         27       210147125.0      18792511.0       22703
#
#    obitosAcumulado  obitosNovos  Recuperadosnovos  emAcompanhamentoNovos  \
# 0           520095         2029        16858632.0              1180443.0
# 1           521952         1857        16931272.0              1170937.0
# 2           523587         1635        16989351.0              1176166.0
# 3           524417          830        17033808.0              1184630.0
# 4           525112          695        17082876.0              1162515.0
#
#    interior/metropolitana
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN

# %%
df_final.describe()
# Out:
#               coduf        codmun  codRegiaoSaude     semanaEpi  \
# count  1.008135e+07  1.003025e+07    9.992580e+06  1.008135e+07
# mean   3.236025e+01  3.252580e+05    3.240312e+04  2.688938e+01
# std    9.873899e+00  9.853503e+04    9.836342e+03  1.505262e+01
# min    1.100000e+01  1.100000e+05    1.100100e+04  1.000000e+00
# 25%    2.500000e+01  2.512000e+05    2.501000e+04  1.400000e+01
# 50%    3.100000e+01  3.146100e+05    3.105900e+04  2.700000e+01
# 75%    4.100000e+01  4.119150e+05    4.101500e+04  4.000000e+01
# max    7.600000e+01  5.300100e+05    5.300100e+04  5.300000e+01
#
#        populacaoTCU2019  casosAcumulado    casosNovos  obitosAcumulado  \
# count      1.004368e+07    1.008135e+07  1.008135e+07     1.008135e+07
# mean       1.139066e+05    1.448174e+04  1.166631e+01     2.963992e+02
# std        2.960280e+06    4.188451e+05  2.288801e+03     8.451936e+03
# min        7.810000e+02    0.000000e+00 -1.412689e+06     0.000000e+00
# 25%        5.474000e+03    4.150000e+02  0.000000e+00     6.000000e+00
# 50%        1.169500e+04    1.118000e+03  0.000000e+00     1.700000e+01
# 75%        2.576200e+04    2.966000e+03  0.000000e+00     4.800000e+01
# max        2.101471e+08    3.920405e+07  1.412689e+06     7.152610e+05
#
#         obitosNovos  Recuperadosnovos  emAcompanhamentoNovos  \
# count  1.008135e+07      1.823000e+03           1.823000e+03
# mean   2.128467e-01      2.570938e+07           3.852953e+05
# std    6.264487e+01      1.361624e+07           5.393898e+05
# min   -4.599700e+04      0.000000e+00          -6.206000e+03
# 25%    0.000000e+00      1.460018e+07           4.106700e+04
# 50%    0.000000e+00      3.329688e+07           1.662580e+05
# 75%    0.000000e+00      3.728000e+07           6.272345e+05
# max    4.599700e+04      3.845905e+07           1.123261e+07
#
#        interior/metropolitana
# count            9.992580e+06
# mean             6.929982e-02
# std              2.539633e-01
# min              0.000000e+00
# 25%              0.000000e+00
# 50%              0.000000e+00
# 75%              0.000000e+00
# max              1.000000e+00

# %%
# df final check

min = df_final['data'].min()
max = df_final['data'].max()

print(f"shape: {df_final.shape}")
print(f"Min: {min}")
print(f"Max: {max}")
# Out:
# shape: (10081354, 17)
# Min: 2020-02-25
# Max: 2025-02-22

# %%
# save to csv

from google.colab import files
df_final.to_csv('df_covid.csv', encoding='utf-8', index=False)
files.download('df_covid.csv')
